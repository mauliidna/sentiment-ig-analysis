# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.8 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import app
from google_play_scraper import Sort, reviews
import numpy as np
import pandas as pd

# %%
# ID aplikasi (dari link Play Store)
app_id = 'com.raimbekov.android.sajde'

# Ambil review (misalnya 100 review teratas)
result, continuation_token = reviews(
    app_id,
    lang='id',        # Bisa juga 'en' untuk Inggris
    country='id',     # Negara
    sort=Sort.NEWEST, # Urutkan berdasarkan yang terbaru
    count=100         # Jumlah review yang ingin diambil
)

# Print review
for r in result:
    print(f"User: {r['userName']}")
    print(f"Rating: {r['score']}")
    print(f"Review: {r['content']}")
    print('-' * 40)
# Out:
# User: Yuli Anti
# Rating: 5
# Review: suka dengan aplikasi nya krna tidak ada iklan saat di dalam apknya dan banyak fitur baru saat ini dan jauh lebih memudahkan dalam penggunaan apk tersebut, masukkan sedikit senang rasanya jika suatu saat apk sajda ini punya fitur scan halal, jadi tidak repot2 buka website lagi untuk mengetahui halal dan tidaknya makanan apabila sedang berada di tempat
# ----------------------------------------
# User: Moch Romli
# Rating: 4
# Review: semoga bermanfaat
# ----------------------------------------
# User: HendZo Hendrawan
# Rating: 5
# Review: Mantap aplikasi gk ada iklan
# ----------------------------------------
# User: Shagy Namja
# Rating: 5
# Review: Good Like
# ----------------------------------------
# User: Mentari Pagi
# Rating: 5
# Review: adzannya bagus banget
# ----------------------------------------
# User: Dah Roni
# Rating: 5
# Review: Masya Allah...
# ----------------------------------------
# User: hendra
# Rating: 5
# Review: bagus
# ...

# %%
df = pd.DataFrame(result)
df.head()
# Out:
#                                reviewId          userName  \
# 0  225ce5b2-c51f-4949-bde0-6634980333bb         Yuli Anti
# 1  4fc724a7-df37-40f9-88bd-d60a7096c99d        Moch Romli
# 2  26d07393-461f-4e8e-9685-6eee172e9261  HendZo Hendrawan
# 3  4b7ac63e-7d94-4945-b6ce-358473dae87c       Shagy Namja
# 4  92e7ad37-e2ed-4245-8a03-95441ded0250      Mentari Pagi
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  suka dengan aplikasi nya krna tidak ada iklan ...      5              0
# 1                                  semoga bermanfaat      4              0
# ...

# %%
df.to_csv('sajda_reviews.csv', index=False)
